# %%
# %pip install scikit-image
# Out:
# Collecting scikit-image
#   Downloading scikit_image-0.19.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.8 MB)
#      |████████████████████████████████| 13.8 MB 1.9 MB/s eta 0:00:01
# Collecting tifffile>=2019.7.26
#   Downloading tifffile-2021.11.2-py3-none-any.whl (178 kB)
#      |████████████████████████████████| 178 kB 3.8 MB/s eta 0:00:01
# Requirement already satisfied: scipy>=1.4.1 in /home/ahmed/.local/bin/.virtualenvs/myEnv/lib/python3.8/site-packages (from scikit-image) (1.7.1)
# Requirement already satisfied: packaging>=20.0 in /home/ahmed/.local/bin/.virtualenvs/myEnv/lib/python3.8/site-packages (from scikit-image) (21.0)
# Collecting imageio>=2.4.1
#   Downloading imageio-2.13.3-py3-none-any.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 4.2 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.17.0 in /home/ahmed/.local/bin/.virtualenvs/myEnv/lib/python3.8/site-packages (from scikit-image) (1.19.5)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /home/ahmed/.local/bin/.virtualenvs/myEnv/lib/python3.8/site-packages (from scikit-image) (8.3.1)
# Collecting PyWavelets>=1.1.1
#   Downloading PyWavelets-1.2.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (6.3 MB)
#      |████████████████████████████████| 6.3 MB 5.9 MB/s eta 0:00:01
# Requirement already satisfied: networkx>=2.2 in /home/ahmed/.local/bin/.virtualenvs/myEnv/lib/python3.8/site-packages (from scikit-image) (2.6.2)
# Collecting pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0
#   Downloading Pillow-8.4.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 3.7 MB/s eta 0:00:01
# Requirement already satisfied: pyparsing>=2.0.2 in /home/ahmed/.local/bin/.virtualenvs/myEnv/lib/python3.8/site-packages (from packaging>=20.0->scikit-image) (2.4.7)
# Installing collected packages: pillow, tifffile, PyWavelets, imageio, scikit-image
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 8.3.1
#     Uninstalling Pillow-8.3.1:
#       Successfully uninstalled Pillow-8.3.1
# Successfully installed PyWavelets-1.2.0 imageio-2.13.3 pillow-8.4.0 scikit-image-0.19.1 tifffile-2021.11.2
# WARNING: You are using pip version 21.2.2; however, version 21.3.1 is available.
# You should consider upgrading via the '/home/ahmed/.local/bin/.virtualenvs/myEnv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### RGB to grayscale

# %%
import matplotlib.pyplot as plt

# %%
def show_image(image, title='Image', cmap_type='gray'):
    plt.imshow(image, cmap=cmap_type)
    plt.title(title)
    plt.axis('off')
    plt.show()

# %%
# Import the modules from skimage
from skimage import data, color

# Load the rocket image
rocket = data.rocket()

# Convert the image to grayscale
gray_scaled_rocket = color.rgb2gray(rocket) 

# Show the original image
show_image(rocket, 'Original RGB image')

# Show the grayscale image
show_image(gray_scaled_rocket, 'Grayscale image')
